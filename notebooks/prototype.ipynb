# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from ydata_profiling import ProfileReport

import os

for dirname, _, filenames in os.walk('../data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../data\D0-titanic.csv
# ../data\diabetes.csv
# ../data\.ipynb_checkpoints\D0-titanic-checkpoint.csv

# %% [markdown]
# # 1.EDA
# Explore and prepare the data for the Synthetic Data Generator (SDG)

# %%
#data = pd.read_csv("../data/D0-titanic.csv")
data = pd.read_csv("../data/diabetes.csv")

data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe().T.round(2)
# Out:
#                           count    mean     std    min    25%     50%     75%  \
# Pregnancies               768.0    3.85    3.37   0.00   1.00    3.00    6.00
# Glucose                   768.0  120.89   31.97   0.00  99.00  117.00  140.25
# BloodPressure             768.0   69.11   19.36   0.00  62.00   72.00   80.00
# SkinThickness             768.0   20.54   15.95   0.00   0.00   23.00   32.00
# Insulin                   768.0   79.80  115.24   0.00   0.00   30.50  127.25
# BMI                       768.0   31.99    7.88   0.00  27.30   32.00   36.60
# DiabetesPedigreeFunction  768.0    0.47    0.33   0.08   0.24    0.37    0.63
# Age                       768.0   33.24   11.76  21.00  24.00   29.00   41.00
# Outcome                   768.0    0.35    0.48   0.00   0.00    0.00    1.00
#
#                              max
# Pregnancies                17.00
# Glucose                   199.00
# BloodPressure             122.00
# SkinThickness              99.00
# ...

# %%
ProfileReport(data, minimal=True, explorative=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.0.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-02-10 04:48:05.349191&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
print("=== Null values: ===\n")
display(data.isnull().sum())
print("\n=== Data types: === \n")
display(data.info())
# Out:
# === Null values: ===
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# === Data types: ===
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
# ...

# %%
#sns.barplot(x='Pclass', y='Survived', data=data)

# %%
from pycaret.classification import *

s = setup(data, target='Outcome', verbose=False)

eda()
# Out:
# Shape of your Data Set loaded: (768, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_0d75e_row0_col0, #T_0d75e_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0d75e_row0_col1, #T_0d75e_row0_col6, #T_0d75e_row1_col1, #T_0d75e_row1_col6, #T_0d75e_row2_col1, #T_0d75e_row2_col6, #T_0d75e_row3_col1, #T_0d75e_row3_col6, #T_0d75e_row4_col1, #T_0d75e_row4_col6, #T_0d75e_row5_col1, #T_0d75e_row5_col6, #T_0d75e_row6_col1, #T_0d75e_row6_col6, #T_0d75e_row7_col1, #T_0d75e_row7_col6 {
#   font-family: Segoe UI;
# }
# ...

# %% [markdown]
# Testing the setup of datasets and saving them as pickles for later processing

# %%
#sns.heatmap(data.corr().round(2), annot=True)
# Define dataset dict, requires dataset name & datset path
dataset = {
    'name': 'D0-Diabetes',
    'path': '../data/diabetes.csv'
}

# %% [markdown]
# Maybe better to straight up use setup_param, and save it as a pickle for the comming pipeline. For each dataset there will be a EDA note, where their respective dataset will be cleaned and model setting will be defined.
#
# #### Question:
# Iterative imputation?

# %%
#Define the setup parameters for pycaret setup function, where the details of preprocessing is defined

setup_param = {
    ### Dataset & target label ###
    'data': pd.read_csv(dataset['path']), # read the dataset from path
    'target': 'Outcome',   # Target label of the dataset, can either be col name or col index
    
    ### Sampling settings ###
    
    'train_size': 0.8, # (float) default=0.7, the train test split used for training and validation
    
    'fold_strategy': 'stratifiedkfold', # (srt), default = 'stratifiedkfold', selects cross-validation method
    
    'fold': 10, #(int) default=10, number of folds
    
    ### Data-preparation settings ###
    
    'ordinal_features': None,         # (dict) default=None, the columns with ordinal values, 
                                      #   e.g. {'column name': ['low', 'med', 'high']}
    
    'numeric_features': None,         # (string[]) default = None, columns that contain numeric values
    
    'text_features': None,            # (string[]) default = None, columns that contain text
    
    'categorical_features': None,     # (string[]) default=None, if inferred types are not correct, 
                                      #    list of column names that are categorical
    
    'imputation_type': 'simple',      # (str or None) default='simple', alternative 'iterative'
    
    'numeric_imputation': 'mean',     # (int, float or str) default='mean', is ignored if imputation_type='iterative'
                                      # alternatives: 
                                      #   'drop'      : drops rows with missing values
                                      #   'mean'      : replace with mean of column
                                      #   'median'    : replace with median of column
                                      #   'mode'      : replace with mode of column 
                                      #   'knn'       : replace with KNN approach
                                      #   int or float: replace with provided value
    
    'categorical_imputation': 'mode', # same as numeric, but only with 'drop', 'mode' and str (replace with str)
    
    ### Data-type settings ###
    #...
    
    ### Logging settings ###
    
    'log_experiment':  True,    # choose logger, alternatives: default='mlflow', 'wandb'
    'experiment_name': 'log_' + dataset['name'],  # name of the experiment in the logger
    'log_plots': False,   # (bool) default=False, if true analysis plots are saved as image files
    'log_data': False,    # (bool) default=Flase, log the train & test datasets as a csv file
    
    ### Backend settings ### (i.g. use the gpu?)
    'n_jobs': -1, #number of jobs to run in parallel (-1 means use all available processors)
    'use_gpu': False, #(bool or str) default=False, whether the GPU should be used for training 
    'html': True, #(bool) default=True, prevents runtime display of the monitor, disable when the env doesn't support IPYTHON
    # (something wrong with this argument, deprecated?)'silent': False, #(bool) default=False, need to be True when executed in a automated setting
    'verbose': True, #(bool) default=True, print information grid?
    'profile': False, #(bool) default=False, if true it displays an interactive EDA report
    'preprocess': True, #(bool) default=True, use preprocessing methods within pycaret?
}

# might not need following, because I will drop the features not neede in preperation of data
# ignore_features = None # (string[]) default=None, list of columns to be ignored in preporcessing and training

# %%
#test saving the object to '../pickles/' directory
import pickle

pickle.dump(setup_param, open('../pickles/D0-setup_param.pkl', 'wb') )

# %% [markdown]
# ---

# %% [markdown]
# # Preprocessing & Classification model

# %%
# test loading up the object for processing
setup_param = pickle.load( open('../pickles/D0-setup_param.pkl', 'rb'))

print(setup_param)
# Out:
# {'data':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
setup_param
# Out:
# {'data':      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  0              6      148             72             35        0  33.6
#  1              1       85             66             29        0  26.6
#  2              8      183             64              0        0  23.3
#  3              1       89             66             23       94  28.1
#  4              0      137             40             35      168  43.1
#  ..           ...      ...            ...            ...      ...   ...
#  763           10      101             76             48      180  32.9
#  764            2      122             70             27        0  36.8
#  765            5      121             72             23      112  26.2
#  766            1      126             60              0        0  30.1
#  767            1       93             70             31        0  30.4
#
#       DiabetesPedigreeFunction  Age  Outcome
#  0                       0.627   50        1
# ...

# %%
from pycaret.classification import *

# %% [markdown]
# Run setup with setup_param as parameter

# %%
# pass the setup_param dictionary as parameters to setup
clf = setup( **setup_param )
# Out:
# <style type="text/css">
# #T_18d70_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_18d70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18d70_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_18d70_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18d70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18d70_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_18d70_row0_col1" class="data row0 col1" >1974</td>
#     </tr>
#     <tr>
#       <th id="T_18d70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18d70_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_18d70_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_18d70_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(sort='F1')
# Out:
# <style type="text/css">
# #T_d0996 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=1974, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ## Optimization

# %%
# Need to define param that should be explored, define which method e.g. grid_search vs random vs optuna
# default search method: random grid search
# Todo: lookup default search range parameters
best_tuned = tune_model(best, optimize='F1', n_iter=200)
# Out:
# <style type="text/css">
# #T_30940_row10_col0, #T_30940_row10_col1, #T_30940_row10_col2, #T_30940_row10_col3, #T_30940_row10_col4, #T_30940_row10_col5, #T_30940_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_30940">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30940_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_30940_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_30940_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_30940_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_30940_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_30940_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_30940_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(best_tuned)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=8,
#                            max_features='log2', max_leaf_nodes=None,
#                            min_impurity_decrease=0.5, min_samples_leaf=2,
#                            min_samples_split=5, min_weight_fraction_leaf=0.0,
#                            n_estimators=270, n_iter_no_change=None,
#                            random_state=1974, subsample=0.75, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
evaluate_model(best_tuned)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Question:
# Should i finalize the model, i.e. train it on all of the data before saving it?

# %%
save_model(model=best_tuned, model_name='../pickles/D0-model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=C:\Users\flore\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'SkinThickness',
#                                               'Insulin', 'BMI',
#                                               'DiabetesPedigreeFunction',
#                                               'Age'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='...
# ...

# %% [markdown]
# ---

# %% [markdown]
# # SDG

# %%
from sdv.tabular import CTGAN

# %%
# parameters for specifically D0
D0_sdg_param = {
    'primary_key': 'Outcome',
    
}

# parameters specifying quality of the SDG
q1 = {
    'epochs': 10,
    'batch_size': 10
}
q2 = {
    'epochs': 50,
    'batch_size': 50
}
q3 = {
    'epochs': 250,
    'batch_size': 500
}
q4 = {
    'epochs': 1250,
    'batch_size': 1000
}

varying_qualities = [ q1, q2, q3 ]

# %% [markdown]
# Are names relevant to include in the generators?

# %%
# need to specify primary_key, meaning the column is the index
model = CTGAN( ** D0_sdg_param, **q1 )

model.fit(data)

# %%
SD = model.sample(num_rows = 300)

# %%
SD.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9       97             56             27      160  32.0
# 1            7       48             80              4       30  35.9
# 2            3      137             73              1      146  61.1
# 3            3      145             53              4      119  34.4
# 4            0      121             99              0        0  22.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.078   37        0
# 1                     0.171   68        1
# 2                     0.363   21        2
# 3                     0.939   21        3
# 4                     0.431   39        4

# %%
ProfileReport(SD, minimal=True, explorative=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.0.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-02-10 05:09:57.027565&quot;&gt;&lt;title&gt;Titanic Dataset&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing & Classification Synthetic data

# %%
sd = setup(SD, target='Outcome', train_size=0.8)
# Out:
# <style type="text/css">
# #T_5e13d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e13d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e13d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5e13d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e13d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e13d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e13d_row0_col1" class="data row0 col1" >1643</td>
#     </tr>
#     <tr>
#       <th id="T_5e13d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e13d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e13d_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_5e13d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d90a3 th {
#   text-align: left;
# }
# ...

# %%
lr = create_model('lr')
tuned = tune_model(lr, n_iter=200, choose_better=True)
# Out:
# <style type="text/css">
# #T_37bbe_row10_col0, #T_37bbe_row10_col1, #T_37bbe_row10_col2, #T_37bbe_row10_col3, #T_37bbe_row10_col4, #T_37bbe_row10_col5, #T_37bbe_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_37bbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37bbe_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_37bbe_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_37bbe_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_37bbe_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_37bbe_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_37bbe_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_37bbe_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
