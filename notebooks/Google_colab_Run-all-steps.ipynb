# %%
# Mount google drive to colab and change to correct directory
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks

# %%
# !cat /etc/lsb-release
# !pwd
# !which python
# !python --version
# !conda --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=20.04
# DISTRIB_CODENAME=focal
# DISTRIB_DESCRIPTION="Ubuntu 20.04.5 LTS"
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks
# /usr/local/bin/python
# Python 3.9.16
# /bin/bash: conda: command not found
# /env/python
# env: PYTHONPATH=

# %%
# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# !pip install -r minimal_requirements.txt
# %cd notebooks
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pandas-profiling in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 2)) (3.6.6)
# Requirement already satisfied: sdv in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: sdmetrics in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 4)) (0.9.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 5)) (0.12.2)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: autopep8 in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: autoviz in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 9)) (0.1.601)
# Requirement already satisfied: kmodes in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 10)) (0.12.2)
# Requirement already satisfied: pomegranate==0.14.8 in /usr/local/lib/python3.9/dist-packages (from -r minimal_requirements.txt (line 11)) (0.14.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from pomegranate==0.14.8->-r minimal_requirements.txt (line 11)) (6.0)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.9/dist-packages (from pomegranate==0.14.8->-r minimal_requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from pomegranate==0.14.8->-r minimal_requirements.txt (line 11)) (1.22.4)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.9/dist-packages (from pomegranate==0.14.8->-r minimal_requirements.txt (line 11)) (3.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.9/dist-packages (from pomegranate==0.14.8->-r minimal_requirements.txt (line 11)) (1.9.3)
# Requirement already satisfied: pyod>=1.0.8 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.13.5)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.8.3.2)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.56.4)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (7.7.1)
# Requirement already satisfied: schemdraw>=0.14 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.16)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (3.3.5)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (5.9.4)
# Requirement already satisfied: sktime>=0.16.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (5.13.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (7.34.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (1.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (5.8.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (0.10.1)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.9/dist-packages (from pycaret->-r minimal_requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.9/dist-packages (from pandas-profiling->-r minimal_requirements.txt (line 2)) (4.1.2)
# Requirement already satisfied: boto3<2,>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (1.26.115)
# Requirement already satisfied: ctgan<0.8,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: copulas<0.9,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: Faker<15,>=10 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (14.2.1)
# Requirement already satisfied: botocore<2,>=1.18 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (1.29.115)
# Requirement already satisfied: rdt<2,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: deepecho<0.5,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sdv->-r minimal_requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (2022.7.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (2.0.9)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (0.17.6)
# Requirement already satisfied: packaging<24 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (21.3)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (1.2.4)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (1.10.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (3.1.31)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (0.4)
# Requirement already satisfied: gunicorn<21 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (20.1.0)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->-r minimal_requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize->-r minimal_requirements.txt (line 7)) (21.10.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.9/dist-packages (from autopep8->-r minimal_requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: pycodestyle>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from autopep8->-r minimal_requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: holoviews>=1.14.6 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (1.15.4)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (2023.4.0)
# Requirement already satisfied: pyamg in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (2.4.3)
# Requirement already satisfied: xgboost>=0.82 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (1.7.5)
# Requirement already satisfied: hvplot>=0.7.3 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: textblob in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (3.8.1)
# Requirement already satisfied: panel>=0.12.6 in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (0.14.4)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (from autoviz->-r minimal_requirements.txt (line 9)) (1.8.2.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic!=1.10.0,<2->mlflow->-r minimal_requirements.txt (line 6)) (1.2.4)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/dist-packages (from bokeh>=2.4.2->autoviz->-r minimal_requirements.txt (line 9)) (8.4.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/dist-packages (from bokeh>=2.4.2->autoviz->-r minimal_requirements.txt (line 9)) (6.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3<2,>=1.15.0->sdv->-r minimal_requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3<2,>=1.15.0->sdv->-r minimal_requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore<2,>=1.18->sdv->-r minimal_requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore<2,>=1.18->sdv->-r minimal_requirements.txt (line 3)) (1.26.15)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders>=2.4.0->pycaret->-r minimal_requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: torch<2,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from ctgan<0.8,>=0.7.1->sdv->-r minimal_requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->-r minimal_requirements.txt (line 6)) (0.8.10)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->-r minimal_requirements.txt (line 6)) (2.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->-r minimal_requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->-r minimal_requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow->-r minimal_requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow->-r minimal_requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow->-r minimal_requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from gitpython<4,>=2.1.0->mlflow->-r minimal_requirements.txt (line 6)) (4.0.10)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.9/dist-packages (from gunicorn<21->mlflow->-r minimal_requirements.txt (line 6)) (67.6.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.9/dist-packages (from holoviews>=1.14.6->autoviz->-r minimal_requirements.txt (line 9)) (2.2.1)
# Requirement already satisfied: param<2.0,>=1.9.3 in /usr/local/lib/python3.9/dist-packages (from holoviews>=1.14.6->autoviz->-r minimal_requirements.txt (line 9)) (1.13.0)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.9/dist-packages (from holoviews>=1.14.6->autoviz->-r minimal_requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn>=0.8.1->pycaret->-r minimal_requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.12.0->pycaret->-r minimal_requirements.txt (line 1)) (3.15.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret->-r minimal_requirements.txt (line 1)) (3.0.7)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret->-r minimal_requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret->-r minimal_requirements.txt (line 1)) (5.5.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret->-r minimal_requirements.txt (line 1)) (3.6.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->pycaret->-r minimal_requirements.txt (line 1)) (0.40.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret->-r minimal_requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret->-r minimal_requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret->-r minimal_requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret->-r minimal_requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret->-r minimal_requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret->-r minimal_requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret->-r minimal_requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret->-r minimal_requirements.txt (line 1)) (2.16.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.55.0->pycaret->-r minimal_requirements.txt (line 1)) (0.39.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from panel>=0.12.6->autoviz->-r minimal_requirements.txt (line 9)) (6.0.0)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.9/dist-packages (from panel>=0.12.6->autoviz->-r minimal_requirements.txt (line 9)) (0.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->pycaret->-r minimal_requirements.txt (line 1)) (8.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (3.8.10)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (2.9.3)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (0.0.9.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r minimal_requirements.txt (line 1)) (0.29.34)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret->-r minimal_requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret->-r minimal_requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret->-r minimal_requirements.txt (line 1)) (3.4)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.9/dist-packages (from sktime>=0.16.1->pycaret->-r minimal_requirements.txt (line 1)) (1.2.13)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r minimal_requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz->-r minimal_requirements.txt (line 9)) (6.5.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz->-r minimal_requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz->-r minimal_requirements.txt (line 9)) (5.4.2)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from jupyter->autoviz->-r minimal_requirements.txt (line 9)) (6.4.8)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->autoviz->-r minimal_requirements.txt (line 9)) (2022.10.31)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (4.3.1)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (1.10.7)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (0.1.12)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (1.9.1)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (2.13.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (0.12.3)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling->-r minimal_requirements.txt (line 2)) (22.2.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret->-r minimal_requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->-r minimal_requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret->-r minimal_requirements.txt (line 1)) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r minimal_requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (1.5.6)
# Requirement already satisfied: retrying in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret->-r minimal_requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret->-r minimal_requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv->-r minimal_requirements.txt (line 3)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv->-r minimal_requirements.txt (line 3)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv->-r minimal_requirements.txt (line 3)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv->-r minimal_requirements.txt (line 3)) (8.5.0.96)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret->-r minimal_requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->panel>=0.12.6->autoviz->-r minimal_requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (4.11.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.7.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (4.9.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from qtconsole->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (2.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz->-r minimal_requirements.txt (line 9)) (2.21)
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks

# %%
import sys
import os 
abs_path = os.path.abspath('../src')
sys.path.append('../src')

# %%
#%run -t Step2-Model.ipynb

# %%
# %run -t Step3-SDG.ipynb

# %%
#%run -t Step4-SD_models.ipynb

# %%
#%run -t Step5-Measures_PF.ipynb

# %% [markdown]
# Below are cells tested for making the colab notebook work. They are not needed, but saved here incase.

# %%
"""
#Deprecated
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
###Downloads conda installer and makes it runnable
#! wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.1.0-1-Linux-x86_64.sh
#! chmod +x Miniconda3-py39_23.1.0-1-Linux-x86_64.sh

! bash ./Miniconda3-py39_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local
# !conda init
"""
# Out:
# "\n#Deprecated\nimport sys\nsys.path.append('/usr/local/lib/python3.9/site-packages/')\n###Downloads conda installer and makes it runnable\n#! wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.1.0-1-Linux-x86_64.sh\n#! chmod +x Miniconda3-py39_23.1.0-1-Linux-x86_64.sh\n\n! bash ./Miniconda3-py39_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local\n!conda init\n"

# %%
#Deprecated
#%cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
#!conda update -y conda -n base
#!conda create -y -n master python=3.9.16
#!conda activate master
#!conda env update -f requirements.yaml -n master
#!conda run -n master python -m ipykernel install --user --name master

# %%
"""
# !pip install pomegranate==0.14.8
# !pip install pycaret
# !pip install pandas-profiling
# !pip install sdv
# !pip install sdmetrics
# !pip install seaborn
# !pip install mlflow
# !pip install scikit-optimize
# !pip install autopep8
# !pip install autoviz
# !pip install kmodes
# %cd notebooks
"""
# Out:
# '\n!pip install pomegranate==0.14.8\n!pip install pycaret\n!pip install pandas-profiling\n!pip install sdv\n!pip install sdmetrics\n!pip install seaborn\n!pip install mlflow\n!pip install scikit-optimize\n!pip install autopep8\n!pip install autoviz\n!pip install kmodes\n%cd notebooks\n'

# %%
# !pip freeze > colab_requirements.txt
