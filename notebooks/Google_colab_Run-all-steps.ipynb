# %%
# !nvidia-smi
# Out:
# Wed Apr 26 01:26:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
try:
  import cuml
except (ImportError, KeyError, ModuleNotFoundError):
  # !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
  # !python rapidsai-csp-utils/colab/pip-install.py

# %%
# Mount google drive to colab and change to correct directory
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23

# %%
# !cat /etc/lsb-release
# !pwd
# !which python
# !python --version
# !conda --version
# !echo $PYTHONPATH
#%env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=20.04
# DISTRIB_CODENAME=focal
# DISTRIB_DESCRIPTION="Ubuntu 20.04.5 LTS"
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# /usr/local/bin/python
# Python 3.9.16
# /bin/bash: conda: command not found
# /env/python
# /env/python

# %%
# Quickfix for dependencies in colab
# Try to import packages, if exception is thrown install dependencies and kill runtime
try:
  from pycaret.classification import *
except (ImportError, KeyError, ModuleNotFoundError):
  ## code to install dependencies
  # !pip install -r colab_requirements.txt
  #!pip install pomegranate==0.14.8  #needed for sdmetrics
  print('Stopping RUNTIME! Colaboratory will restart automatically. Please run again.')
  import os
  os.kill(os.getpid(), 9)

# %%
# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks

# %%
# %run -t Step-2_Classification_GPU.ipynb
# Out:
# Start models for D1-titanic
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     272         try:
# --> 273             return self[key]
#     274         except KeyError:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in __getitem__(self, arg)
#    1170         if _is_scalar_or_zero_d_array(arg) or isinstance(arg, tuple):
# -> 1171             return self._get_columns_by_label(arg, downcast=True)
#    1172
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in _get_columns_by_label(self, labels, downcast)
#    1914         """
# -> 1915         new_data = super()._get_columns_by_label(labels, downcast)
#    1916         if downcast:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _get_columns_by_label(self, labels, downcast)
#     418         """
# --> 419         return self._data.select_by_label(labels)
#     420
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in select_by_label(self, key)
#     354                     return self._select_by_label_with_wildcard(key)
# --> 355             return self._select_by_label_grouped(key)
#     356
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in _select_by_label_grouped(self, key)
#     474     def _select_by_label_grouped(self, key: Any) -> ColumnAccessor:
# --> 475         result = self._grouped_data[key]
#     476         if isinstance(result, cudf.core.column.ColumnBase):
#
# KeyError: '__cuda_array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1209     try:
# -> 1210         array_interface = arr.__cuda_array_interface__
#    1211     except AttributeError:
#
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     274         except KeyError:
# --> 275             raise AttributeError(
#     276                 f"{type(self).__name__} object has no attribute {key}"
#
# AttributeError: DataFrame object has no attribute __cuda_array_interface__
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     272         try:
# --> 273             return self[key]
#     274         except KeyError:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in __getitem__(self, arg)
#    1170         if _is_scalar_or_zero_d_array(arg) or isinstance(arg, tuple):
# -> 1171             return self._get_columns_by_label(arg, downcast=True)
#    1172
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in _get_columns_by_label(self, labels, downcast)
#    1914         """
# -> 1915         new_data = super()._get_columns_by_label(labels, downcast)
#    1916         if downcast:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _get_columns_by_label(self, labels, downcast)
#     418         """
# --> 419         return self._data.select_by_label(labels)
#     420
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in select_by_label(self, key)
#     354                     return self._select_by_label_with_wildcard(key)
# --> 355             return self._select_by_label_grouped(key)
#     356
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in _select_by_label_grouped(self, key)
#     474     def _select_by_label_grouped(self, key: Any) -> ColumnAccessor:
# --> 475         result = self._grouped_data[key]
#     476         if isinstance(result, cudf.core.column.ColumnBase):
#
# KeyError: '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1212         try:
# -> 1213             array_interface = arr.__array_interface__
#    1214         except AttributeError:
#
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     274         except KeyError:
# --> 275             raise AttributeError(
#     276                 f"{type(self).__name__} object has no attribute {key}"
#
# AttributeError: DataFrame object has no attribute __array_interface__
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step-2_Classification_GPU.ipynb in <cell line: 3>()
#      28
#      29     # Split the dataset into a train set and a test set using cuML's train_test_split function
# ---> 30     x_train, x_test, y_train, y_test = train_test_split(
#      31         X=original_data.drop(target_label, axis=1),
#      32         y=original_data[target_label],
#
# /usr/local/lib/python3.9/dist-packages/cuml/model_selection/_split.py in train_test_split(X, y, test_size, train_size, shuffle, random_state, stratify)
#     458                 stratify = cp.asarray(stratify)[idxs]
#     459
# --> 460             split_return = _stratify_split(
#     461                 X,
#     462                 stratify,
#
# /usr/local/lib/python3.9/dist-packages/cuml/model_selection/_split.py in _stratify_split(X, stratify, labels, n_train, n_test, x_numba, y_numba, random_state)
#      57     elif hasattr(X, "__cuda_array_interface__"):
#      58         X = cp.asarray(X)
# ---> 59     x_order = array_to_memory_order(X)
#      60
#      61     # labels and stratify will be only cp arrays
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1213             array_interface = arr.__array_interface__
#    1214         except AttributeError:
# -> 1215             return array_to_memory_order(CumlArray.from_input(arr, order="K"))
#    1216     strides = array_interface.get("strides", None)
#    1217     if strides is None:
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/memory_utils.py in cupy_rmm_wrapper(*args, **kwargs)
#      85         if GPU_ENABLED:
#      86             with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87                 return func(*args, **kwargs)
#      88         return func(*args, **kwargs)
#      89
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#      99         def inner(*args, **kwargs):
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#     103             return result
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1070             X = X.to_numpy(copy=False)
#    1071         if isinstance(X, CudfDataFrame):
# -> 1072             X = X.to_cupy(copy=False)
#    1073
#    1074         requested_order = (order, None)[fail_on_order]
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#      99         def inner(*args, **kwargs):
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#     103             return result
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in to_cupy(self, dtype, copy, na_value)
#     543         cupy.ndarray
#     544         """
# --> 545         return self._to_array(
#     546             (lambda col: col.values.copy())
#     547             if copy
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _to_array(self, get_column_values, make_empty_matrix, dtype, na_value)
#     508             # unsupported dtype. We may want to catch and provide a more
#     509             # suitable error.
# --> 510             matrix[:, i] = get_column_values_na(col)
#     511         return matrix
#     512
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base.__setitem__()
#
# cupy/_core/_routines_indexing.pyx in cupy._core._routines_indexing._ndarray_setitem()
#
# cupy/_core/_routines_indexing.pyx in cupy._core._routines_indexing._scatter_op()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel.ufunc.__call__()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel.ufunc._get_ufunc_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_ufunc_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_simple_elementwise_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_kernel_params()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._ArgInfo.get_param_c_type()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._ArgInfo.get_c_type()
#
# cupy/_core/_scalar.pyx in cupy._core._scalar.get_typename()
#
# cupy/_core/_scalar.pyx in cupy._core._scalar.get_typename()
#
# KeyError: <class 'numpy.object_'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     272         try:
# --> 273             return self[key]
#     274         except KeyError:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in __getitem__(self, arg)
#    1170         if _is_scalar_or_zero_d_array(arg) or isinstance(arg, tuple):
# -> 1171             return self._get_columns_by_label(arg, downcast=True)
#    1172
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in _get_columns_by_label(self, labels, downcast)
#    1914         """
# -> 1915         new_data = super()._get_columns_by_label(labels, downcast)
#    1916         if downcast:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _get_columns_by_label(self, labels, downcast)
#     418         """
# --> 419         return self._data.select_by_label(labels)
#     420
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in select_by_label(self, key)
#     354                     return self._select_by_label_with_wildcard(key)
# --> 355             return self._select_by_label_grouped(key)
#     356
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in _select_by_label_grouped(self, key)
#     474     def _select_by_label_grouped(self, key: Any) -> ColumnAccessor:
# --> 475         result = self._grouped_data[key]
#     476         if isinstance(result, cudf.core.column.ColumnBase):
#
# KeyError: '__cuda_array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1209     try:
# -> 1210         array_interface = arr.__cuda_array_interface__
#    1211     except AttributeError:
#
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     274         except KeyError:
# --> 275             raise AttributeError(
#     276                 f"{type(self).__name__} object has no attribute {key}"
#
# AttributeError: DataFrame object has no attribute __cuda_array_interface__
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     272         try:
# --> 273             return self[key]
#     274         except KeyError:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in __getitem__(self, arg)
#    1170         if _is_scalar_or_zero_d_array(arg) or isinstance(arg, tuple):
# -> 1171             return self._get_columns_by_label(arg, downcast=True)
#    1172
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/dataframe.py in _get_columns_by_label(self, labels, downcast)
#    1914         """
# -> 1915         new_data = super()._get_columns_by_label(labels, downcast)
#    1916         if downcast:
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _get_columns_by_label(self, labels, downcast)
#     418         """
# --> 419         return self._data.select_by_label(labels)
#     420
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in select_by_label(self, key)
#     354                     return self._select_by_label_with_wildcard(key)
# --> 355             return self._select_by_label_grouped(key)
#     356
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/column_accessor.py in _select_by_label_grouped(self, key)
#     474     def _select_by_label_grouped(self, key: Any) -> ColumnAccessor:
# --> 475         result = self._grouped_data[key]
#     476         if isinstance(result, cudf.core.column.ColumnBase):
#
# KeyError: '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1212         try:
# -> 1213             array_interface = arr.__array_interface__
#    1214         except AttributeError:
#
# /usr/local/lib/python3.9/dist-packages/cudf/utils/utils.py in __getattr__(self, key)
#     274         except KeyError:
# --> 275             raise AttributeError(
#     276                 f"{type(self).__name__} object has no attribute {key}"
#
# AttributeError: DataFrame object has no attribute __array_interface__
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6ab9e0764e8c> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '-t Step-2_Classification_GPU.ipynb')
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2903                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2904                     if raise_exceptions:
# -> 2905                         result.raise_error()
#    2906                     elif not result.success:
#    2907                         break
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in raise_error(self)
#     347             raise self.error_before_exec
#     348         if self.error_in_exec is not None:
# --> 349             raise self.error_in_exec
#     350
#     351     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-8-ba0068000605> in <cell line: 3>()
#      28
#      29     # Split the dataset into a train set and a test set using cuML's train_test_split function
# ---> 30     x_train, x_test, y_train, y_test = train_test_split(
#      31         X=original_data.drop(target_label, axis=1),
#      32         y=original_data[target_label],
#
# /usr/local/lib/python3.9/dist-packages/cuml/model_selection/_split.py in train_test_split(X, y, test_size, train_size, shuffle, random_state, stratify)
#     458                 stratify = cp.asarray(stratify)[idxs]
#     459
# --> 460             split_return = _stratify_split(
#     461                 X,
#     462                 stratify,
#
# /usr/local/lib/python3.9/dist-packages/cuml/model_selection/_split.py in _stratify_split(X, stratify, labels, n_train, n_test, x_numba, y_numba, random_state)
#      57     elif hasattr(X, "__cuda_array_interface__"):
#      58         X = cp.asarray(X)
# ---> 59     x_order = array_to_memory_order(X)
#      60
#      61     # labels and stratify will be only cp arrays
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in array_to_memory_order(arr, default)
#    1213             array_interface = arr.__array_interface__
#    1214         except AttributeError:
# -> 1215             return array_to_memory_order(CumlArray.from_input(arr, order="K"))
#    1216     strides = array_interface.get("strides", None)
#    1217     if strides is None:
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/memory_utils.py in cupy_rmm_wrapper(*args, **kwargs)
#      85         if GPU_ENABLED:
#      86             with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87                 return func(*args, **kwargs)
#      88         return func(*args, **kwargs)
#      89
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#      99         def inner(*args, **kwargs):
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#     103             return result
#
# /usr/local/lib/python3.9/dist-packages/cuml/internals/array.py in from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1070             X = X.to_numpy(copy=False)
#    1071         if isinstance(X, CudfDataFrame):
# -> 1072             X = X.to_cupy(copy=False)
#    1073
#    1074         requested_order = (order, None)[fail_on_order]
#
# /usr/local/lib/python3.9/dist-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#      99         def inner(*args, **kwargs):
#     100             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101             result = func(*args, **kwargs)
#     102             libnvtx_pop_range(self.domain.handle)
#     103             return result
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in to_cupy(self, dtype, copy, na_value)
#     543         cupy.ndarray
#     544         """
# --> 545         return self._to_array(
#     546             (lambda col: col.values.copy())
#     547             if copy
#
# /usr/local/lib/python3.9/dist-packages/cudf/core/frame.py in _to_array(self, get_column_values, make_empty_matrix, dtype, na_value)
#     508             # unsupported dtype. We may want to catch and provide a more
#     509             # suitable error.
# --> 510             matrix[:, i] = get_column_values_na(col)
#     511         return matrix
#     512
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base.__setitem__()
#
# cupy/_core/_routines_indexing.pyx in cupy._core._routines_indexing._ndarray_setitem()
#
# cupy/_core/_routines_indexing.pyx in cupy._core._routines_indexing._scatter_op()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel.ufunc.__call__()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel.ufunc._get_ufunc_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_ufunc_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_simple_elementwise_kernel()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._get_kernel_params()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._ArgInfo.get_param_c_type()
#
# cupy/_core/_kernel.pyx in cupy._core._kernel._ArgInfo.get_c_type()
#
# cupy/_core/_scalar.pyx in cupy._core._scalar.get_typename()
#
# cupy/_core/_scalar.pyx in cupy._core._scalar.get_typename()
#
# KeyError: <class 'numpy.object_'>

# %%
#%run -t Step3-SDG.ipynb

# %%
#%run -t Step4-SD_models.ipynb

# %%
#%run -t Step5-Measures_PF.ipynb

# %% [markdown]
# Below are cells tested for making the colab notebook work. They are not needed, but saved here incase.

# %%
"""
# !pip install pycaret
# !pip install pandas-profiling
# !pip install sdv
# !pip install sdmetrics
# !pip install seaborn
# !pip install mlflow
# !pip install scikit-optimize
# !pip install autopep8
# !pip install autoviz
# !pip install kmodes
# !pip install pomegranate==0.14.8
# %cd notebooks
"""

# %%
"""
#Deprecated
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
###Downloads conda installer and makes it runnable
#! wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.1.0-1-Linux-x86_64.sh
#! chmod +x Miniconda3-py39_23.1.0-1-Linux-x86_64.sh

! bash ./Miniconda3-py39_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local
# !conda init
"""

# %%
#Deprecated
#%cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
#!conda update -y conda -n base
#!conda create -y -n master python=3.9.16
#!conda activate master
#!conda env update -f requirements.yaml -n master
#!conda run -n master python -m ipykernel install --user --name master

# %%
#!pip freeze > ../colab_requirements.txt
