# %%
# Mount google drive to colab and change to correct directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23

# %%
# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# !cat /etc/lsb-release
# !pwd
# !which python
# !python --version
# !conda --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=20.04
# DISTRIB_CODENAME=focal
# DISTRIB_DESCRIPTION="Ubuntu 20.04.5 LTS"
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# /usr/local/bin/python
# Python 3.9.16
# /bin/bash: conda: command not found
# /env/python
# env: PYTHONPATH=

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11148312192528906936
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14343274496
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13815405753232784271
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# Quickfix for dependencies in colab
# Try to import packages, if exception is thrown install dependencies and kill runtime
try:
  from pycaret.classification import *
except (ImportError, KeyError, ModuleNotFoundError):
  ## code to install dependencies
  # !pip install -r minimal_requirements.txt
  #!pip install pomegranate==0.14.8
  print('Stopping RUNTIME! Colaboratory will restart automatically. Please run again.')
  import os
  os.kill(os.getpid(), 9)

# %%
# %cd notebooks
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks

# %%
import sys
import os 
abs_path = os.path.abspath('../src')
sys.path.append('../src')

# %%
# %run -t Step2-Model.ipynb
# Out:
# <style type="text/css">
# #T_4945d_row8_col1, #T_4945d_row10_col1, #T_4945d_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4945d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4945d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4945d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4945d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4945d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4945d_row0_col1" class="data row0 col1" >1927</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4945d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4945d_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4945d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4945d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4945d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4945d_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4945d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4945d_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4945d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4945d_row5_col1" class="data row5 col1" >(614, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4945d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4945d_row6_col1" class="data row6 col1" >(154, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4945d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4945d_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4945d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4945d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4945d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4945d_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4945d_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_4945d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4945d_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_4945d_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4945d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4945d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4945d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4945d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4945d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4945d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4945d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4945d_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4945d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4945d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4945d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4945d_row17_col1" class="data row17 col1" >D0-Diabetes</td>
#     </tr>
#     <tr>
#       <th id="T_4945d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4945d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4945d_row18_col1" class="data row18 col1" >4ab2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ad2cd_row10_col0, #T_ad2cd_row10_col1, #T_ad2cd_row10_col2, #T_ad2cd_row10_col3, #T_ad2cd_row10_col4, #T_ad2cd_row10_col5, #T_ad2cd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ad2cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad2cd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ad2cd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ad2cd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ad2cd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ad2cd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ad2cd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ad2cd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad2cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad2cd_row0_col0" class="data row0 col0" >0.7258</td>
#       <td id="T_ad2cd_row0_col1" class="data row0 col1" >0.7807</td>
#       <td id="T_ad2cd_row0_col2" class="data row0 col2" >0.5455</td>
#       <td id="T_ad2cd_row0_col3" class="data row0 col3" >0.6316</td>
#       <td id="T_ad2cd_row0_col4" class="data row0 col4" >0.5854</td>
#       <td id="T_ad2cd_row0_col5" class="data row0 col5" >0.3822</td>
#       <td id="T_ad2cd_row0_col6" class="data row0 col6" >0.3845</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad2cd_row1_col0" class="data row1 col0" >0.6774</td>
#       <td id="T_ad2cd_row1_col1" class="data row1 col1" >0.8227</td>
#       <td id="T_ad2cd_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_ad2cd_row1_col3" class="data row1 col3" >0.5500</td>
#       <td id="T_ad2cd_row1_col4" class="data row1 col4" >0.5238</td>
#       <td id="T_ad2cd_row1_col5" class="data row1 col5" >0.2807</td>
#       <td id="T_ad2cd_row1_col6" class="data row1 col6" >0.2815</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad2cd_row2_col0" class="data row2 col0" >0.6613</td>
#       <td id="T_ad2cd_row2_col1" class="data row2 col1" >0.6909</td>
#       <td id="T_ad2cd_row2_col2" class="data row2 col2" >0.4091</td>
#       <td id="T_ad2cd_row2_col3" class="data row2 col3" >0.5294</td>
#       <td id="T_ad2cd_row2_col4" class="data row2 col4" >0.4615</td>
#       <td id="T_ad2cd_row2_col5" class="data row2 col5" >0.2204</td>
#       <td id="T_ad2cd_row2_col6" class="data row2 col6" >0.2243</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad2cd_row3_col0" class="data row3 col0" >0.7581</td>
#       <td id="T_ad2cd_row3_col1" class="data row3 col1" >0.8000</td>
#       <td id="T_ad2cd_row3_col2" class="data row3 col2" >0.5455</td>
#       <td id="T_ad2cd_row3_col3" class="data row3 col3" >0.7059</td>
#       <td id="T_ad2cd_row3_col4" class="data row3 col4" >0.6154</td>
#       <td id="T_ad2cd_row3_col5" class="data row3 col5" >0.4431</td>
#       <td id="T_ad2cd_row3_col6" class="data row3 col6" >0.4510</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad2cd_row4_col0" class="data row4 col0" >0.7541</td>
#       <td id="T_ad2cd_row4_col1" class="data row4 col1" >0.8500</td>
#       <td id="T_ad2cd_row4_col2" class="data row4 col2" >0.7619</td>
#       <td id="T_ad2cd_row4_col3" class="data row4 col3" >0.6154</td>
#       <td id="T_ad2cd_row4_col4" class="data row4 col4" >0.6809</td>
#       <td id="T_ad2cd_row4_col5" class="data row4 col5" >0.4845</td>
#       <td id="T_ad2cd_row4_col6" class="data row4 col6" >0.4918</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad2cd_row5_col0" class="data row5 col0" >0.8197</td>
#       <td id="T_ad2cd_row5_col1" class="data row5 col1" >0.9071</td>
#       <td id="T_ad2cd_row5_col2" class="data row5 col2" >0.7619</td>
#       <td id="T_ad2cd_row5_col3" class="data row5 col3" >0.7273</td>
#       <td id="T_ad2cd_row5_col4" class="data row5 col4" >0.7442</td>
#       <td id="T_ad2cd_row5_col5" class="data row5 col5" >0.6051</td>
#       <td id="T_ad2cd_row5_col6" class="data row5 col6" >0.6055</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad2cd_row6_col0" class="data row6 col0" >0.6885</td>
#       <td id="T_ad2cd_row6_col1" class="data row6 col1" >0.7857</td>
#       <td id="T_ad2cd_row6_col2" class="data row6 col2" >0.4762</td>
#       <td id="T_ad2cd_row6_col3" class="data row6 col3" >0.5556</td>
#       <td id="T_ad2cd_row6_col4" class="data row6 col4" >0.5128</td>
#       <td id="T_ad2cd_row6_col5" class="data row6 col5" >0.2859</td>
#       <td id="T_ad2cd_row6_col6" class="data row6 col6" >0.2877</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad2cd_row7_col0" class="data row7 col0" >0.8689</td>
#       <td id="T_ad2cd_row7_col1" class="data row7 col1" >0.8774</td>
#       <td id="T_ad2cd_row7_col2" class="data row7 col2" >0.8095</td>
#       <td id="T_ad2cd_row7_col3" class="data row7 col3" >0.8095</td>
#       <td id="T_ad2cd_row7_col4" class="data row7 col4" >0.8095</td>
#       <td id="T_ad2cd_row7_col5" class="data row7 col5" >0.7095</td>
#       <td id="T_ad2cd_row7_col6" class="data row7 col6" >0.7095</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad2cd_row8_col0" class="data row8 col0" >0.7705</td>
#       <td id="T_ad2cd_row8_col1" class="data row8 col1" >0.8500</td>
#       <td id="T_ad2cd_row8_col2" class="data row8 col2" >0.8571</td>
#       <td id="T_ad2cd_row8_col3" class="data row8 col3" >0.6207</td>
#       <td id="T_ad2cd_row8_col4" class="data row8 col4" >0.7200</td>
#       <td id="T_ad2cd_row8_col5" class="data row8 col5" >0.5338</td>
#       <td id="T_ad2cd_row8_col6" class="data row8 col6" >0.5539</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ad2cd_row9_col0" class="data row9 col0" >0.7541</td>
#       <td id="T_ad2cd_row9_col1" class="data row9 col1" >0.8179</td>
#       <td id="T_ad2cd_row9_col2" class="data row9 col2" >0.6667</td>
#       <td id="T_ad2cd_row9_col3" class="data row9 col3" >0.6364</td>
#       <td id="T_ad2cd_row9_col4" class="data row9 col4" >0.6512</td>
#       <td id="T_ad2cd_row9_col5" class="data row9 col5" >0.4614</td>
#       <td id="T_ad2cd_row9_col6" class="data row9 col6" >0.4617</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ad2cd_row10_col0" class="data row10 col0" >0.7478</td>
#       <td id="T_ad2cd_row10_col1" class="data row10 col1" >0.8182</td>
#       <td id="T_ad2cd_row10_col2" class="data row10 col2" >0.6333</td>
#       <td id="T_ad2cd_row10_col3" class="data row10 col3" >0.6382</td>
#       <td id="T_ad2cd_row10_col4" class="data row10 col4" >0.6305</td>
#       <td id="T_ad2cd_row10_col5" class="data row10 col5" >0.4407</td>
#       <td id="T_ad2cd_row10_col6" class="data row10 col6" >0.4451</td>
#     </tr>
#     <tr>
#       <th id="T_ad2cd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ad2cd_row11_col0" class="data row11 col0" >0.0608</td>
#       <td id="T_ad2cd_row11_col1" class="data row11 col1" >0.0570</td>
#       <td id="T_ad2cd_row11_col2" class="data row11 col2" >0.1495</td>
#       <td id="T_ad2cd_row11_col3" class="data row11 col3" >0.0832</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# <style type="text/css">
# </style>
# <table id="T_4f0f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f0f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4f0f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4f0f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4f0f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4f0f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4f0f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4f0f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4f0f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f0f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f0f3_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_4f0f3_row0_col1" class="data row0 col1" >0.7597</td>
#       <td id="T_4f0f3_row0_col2" class="data row0 col2" >0.8417</td>
#       <td id="T_4f0f3_row0_col3" class="data row0 col3" >0.6667</td>
#       <td id="T_4f0f3_row0_col4" class="data row0 col4" >0.6545</td>
#       <td id="T_4f0f3_row0_col5" class="data row0 col5" >0.6606</td>
#       <td id="T_4f0f3_row0_col6" class="data row0 col6" >0.4746</td>
#       <td id="T_4f0f3_row0_col7" class="data row0 col7" >0.4747</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %run -t Step3-SDG.ipynb
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step3-SDG.ipynb in <cell line: 12>()
#      49         #model.fit(original_data)
#      50
# ---> 51         model, stdout_loss = train_sdg_model(model, original_data, sdg_name)
#      52         # extract loss, create loss plot and save it
#      53         loss_dict = extract_loss_info_from_stdout(stdout_loss)
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step3-SDG.ipynb in wrapper(*args, **kwargs)
#      11
#      12         # Call the original function and get its output
# ---> 13         func_output = func(*args, **kwargs)
#      14
#      15         # Retrieve the captured stdout
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step3-SDG.ipynb in train_sdg_model(model, data, sdg_name)
#      28     print("#START#")
#      29     print(sdg_name)
# ---> 30     model.fit(data)
#      31     print("#END#")
#      32
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/base.py in fit(self, data)
#     455         self._random_state_set = False
#     456         processed_data = self._preprocess(data)
# --> 457         self.fit_processed_data(processed_data)
#     458
#     459     def save(self, filepath):
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/base.py in fit_processed_data(self, processed_data)
#     439                 The transformed data used to fit the model to.
#     440         """
# --> 441         self._fit(processed_data)
#     442         self._fitted = True
#     443         self._fitted_date = datetime.datetime.today().strftime('%Y-%m-%d')
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/ctgan.py in _fit(self, processed_data)
#     111         """
#     112         discrete_columns = detect_discrete_columns(self.get_metadata(), processed_data)
# --> 113         self._model = CTGAN(**self._model_kwargs)
#     114         self._model.fit(processed_data, discrete_columns=discrete_columns)
#     115
#
# /usr/local/lib/python3.9/dist-packages/ctgan/synthesizers/ctgan.py in __init__(self, embedding_dim, generator_dim, discriminator_dim, generator_lr, generator_decay, discriminator_lr, discriminator_decay, batch_size, discriminator_steps, log_frequency, verbose, epochs, pac, cuda)
#     171             device = 'cuda'
#     172
# --> 173         self._device = torch.device(device)
#     174
#     175         self._transformer = None
#
# RuntimeError: Invalid device string: '/device:GPU:0'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-77a3915fbcf3> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '-t Step3-SDG.ipynb')
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2903                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2904                     if raise_exceptions:
# -> 2905                         result.raise_error()
#    2906                     elif not result.success:
#    2907                         break
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in raise_error(self)
#     347             raise self.error_before_exec
#     348         if self.error_in_exec is not None:
# --> 349             raise self.error_in_exec
#     350
#     351     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-5-797394e1dc7d> in <cell line: 12>()
#      49         #model.fit(original_data)
#      50
# ---> 51         model, stdout_loss = train_sdg_model(model, original_data, sdg_name)
#      52         # extract loss, create loss plot and save it
#      53         loss_dict = extract_loss_info_from_stdout(stdout_loss)
#
# <ipython-input-5-65ce92ace624> in wrapper(*args, **kwargs)
#      11
#      12         # Call the original function and get its output
# ---> 13         func_output = func(*args, **kwargs)
#      14
#      15         # Retrieve the captured stdout
#
# <ipython-input-5-65ce92ace624> in train_sdg_model(model, data, sdg_name)
#      28     print("#START#")
#      29     print(sdg_name)
# ---> 30     model.fit(data)
#      31     print("#END#")
#      32
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/base.py in fit(self, data)
#     455         self._random_state_set = False
#     456         processed_data = self._preprocess(data)
# --> 457         self.fit_processed_data(processed_data)
#     458
#     459     def save(self, filepath):
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/base.py in fit_processed_data(self, processed_data)
#     439                 The transformed data used to fit the model to.
#     440         """
# --> 441         self._fit(processed_data)
#     442         self._fitted = True
#     443         self._fitted_date = datetime.datetime.today().strftime('%Y-%m-%d')
#
# /usr/local/lib/python3.9/dist-packages/sdv/single_table/ctgan.py in _fit(self, processed_data)
#     111         """
#     112         discrete_columns = detect_discrete_columns(self.get_metadata(), processed_data)
# --> 113         self._model = CTGAN(**self._model_kwargs)
#     114         self._model.fit(processed_data, discrete_columns=discrete_columns)
#     115
#
# /usr/local/lib/python3.9/dist-packages/ctgan/synthesizers/ctgan.py in __init__(self, embedding_dim, generator_dim, discriminator_dim, generator_lr, generator_decay, discriminator_lr, discriminator_decay, batch_size, discriminator_steps, log_frequency, verbose, epochs, pac, cuda)
#     171             device = 'cuda'
#     172
# --> 173         self._device = torch.device(device)
#     174
#     175         self._transformer = None
#
# RuntimeError: Invalid device string: '/device:GPU:0'

# %%
# %run -t Step4-SD_models.ipynb
# Out:
# <style type="text/css">
# #T_dfa4f_row8_col1, #T_dfa4f_row10_col1, #T_dfa4f_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dfa4f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfa4f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dfa4f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfa4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfa4f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dfa4f_row0_col1" class="data row0 col1" >2163</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfa4f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dfa4f_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfa4f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dfa4f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfa4f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_dfa4f_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfa4f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_dfa4f_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dfa4f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_dfa4f_row5_col1" class="data row5 col1" >(614, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dfa4f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_dfa4f_row6_col1" class="data row6 col1" >(154, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dfa4f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_dfa4f_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dfa4f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_dfa4f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dfa4f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_dfa4f_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dfa4f_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_dfa4f_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dfa4f_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_dfa4f_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dfa4f_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_dfa4f_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dfa4f_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_dfa4f_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dfa4f_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_dfa4f_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dfa4f_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_dfa4f_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dfa4f_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_dfa4f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dfa4f_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_dfa4f_row17_col1" class="data row17 col1" >D0-Diabetes</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dfa4f_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_dfa4f_row18_col1" class="data row18 col1" >d866</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_581fd_row10_col0, #T_581fd_row10_col1, #T_581fd_row10_col2, #T_581fd_row10_col3, #T_581fd_row10_col4, #T_581fd_row10_col5, #T_581fd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_581fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_581fd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_581fd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_581fd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_581fd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_581fd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_581fd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_581fd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_581fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_581fd_row0_col0" class="data row0 col0" >0.5323</td>
#       <td id="T_581fd_row0_col1" class="data row0 col1" >0.5323</td>
#       <td id="T_581fd_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_581fd_row0_col3" class="data row0 col3" >0.5167</td>
#       <td id="T_581fd_row0_col4" class="data row0 col4" >0.6813</td>
#       <td id="T_581fd_row0_col5" class="data row0 col5" >0.0645</td>
#       <td id="T_581fd_row0_col6" class="data row0 col6" >0.1826</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_581fd_row1_col0" class="data row1 col0" >0.5323</td>
#       <td id="T_581fd_row1_col1" class="data row1 col1" >0.5323</td>
#       <td id="T_581fd_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_581fd_row1_col3" class="data row1 col3" >0.5167</td>
#       <td id="T_581fd_row1_col4" class="data row1 col4" >0.6813</td>
#       <td id="T_581fd_row1_col5" class="data row1 col5" >0.0645</td>
#       <td id="T_581fd_row1_col6" class="data row1 col6" >0.1826</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_581fd_row2_col0" class="data row2 col0" >0.5484</td>
#       <td id="T_581fd_row2_col1" class="data row2 col1" >0.5484</td>
#       <td id="T_581fd_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_581fd_row2_col3" class="data row2 col3" >0.5254</td>
#       <td id="T_581fd_row2_col4" class="data row2 col4" >0.6889</td>
#       <td id="T_581fd_row2_col5" class="data row2 col5" >0.0968</td>
#       <td id="T_581fd_row2_col6" class="data row2 col6" >0.2255</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_581fd_row3_col0" class="data row3 col0" >0.5645</td>
#       <td id="T_581fd_row3_col1" class="data row3 col1" >0.5645</td>
#       <td id="T_581fd_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_581fd_row3_col3" class="data row3 col3" >0.5345</td>
#       <td id="T_581fd_row3_col4" class="data row3 col4" >0.6966</td>
#       <td id="T_581fd_row3_col5" class="data row3 col5" >0.1290</td>
#       <td id="T_581fd_row3_col6" class="data row3 col6" >0.2626</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_581fd_row4_col0" class="data row4 col0" >0.5082</td>
#       <td id="T_581fd_row4_col1" class="data row4 col1" >0.5161</td>
#       <td id="T_581fd_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_581fd_row4_col3" class="data row4 col3" >0.5000</td>
#       <td id="T_581fd_row4_col4" class="data row4 col4" >0.6667</td>
#       <td id="T_581fd_row4_col5" class="data row4 col5" >0.0317</td>
#       <td id="T_581fd_row4_col6" class="data row4 col6" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_581fd_row5_col0" class="data row5 col0" >0.5246</td>
#       <td id="T_581fd_row5_col1" class="data row5 col1" >0.5323</td>
#       <td id="T_581fd_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_581fd_row5_col3" class="data row5 col3" >0.5085</td>
#       <td id="T_581fd_row5_col4" class="data row5 col4" >0.6742</td>
#       <td id="T_581fd_row5_col5" class="data row5 col5" >0.0635</td>
#       <td id="T_581fd_row5_col6" class="data row5 col6" >0.1811</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_581fd_row6_col0" class="data row6 col0" >0.4754</td>
#       <td id="T_581fd_row6_col1" class="data row6 col1" >0.4833</td>
#       <td id="T_581fd_row6_col2" class="data row6 col2" >0.9667</td>
#       <td id="T_581fd_row6_col3" class="data row6 col3" >0.4833</td>
#       <td id="T_581fd_row6_col4" class="data row6 col4" >0.6444</td>
#       <td id="T_581fd_row6_col5" class="data row6 col5" >-0.0328</td>
#       <td id="T_581fd_row6_col6" class="data row6 col6" >-0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_581fd_row7_col0" class="data row7 col0" >0.4918</td>
#       <td id="T_581fd_row7_col1" class="data row7 col1" >0.5016</td>
#       <td id="T_581fd_row7_col2" class="data row7 col2" >0.9000</td>
#       <td id="T_581fd_row7_col3" class="data row7 col3" >0.4909</td>
#       <td id="T_581fd_row7_col4" class="data row7 col4" >0.6353</td>
#       <td id="T_581fd_row7_col5" class="data row7 col5" >-0.0032</td>
#       <td id="T_581fd_row7_col6" class="data row7 col6" >-0.0054</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_581fd_row8_col0" class="data row8 col0" >0.5410</td>
#       <td id="T_581fd_row8_col1" class="data row8 col1" >0.5473</td>
#       <td id="T_581fd_row8_col2" class="data row8 col2" >0.9667</td>
#       <td id="T_581fd_row8_col3" class="data row8 col3" >0.5179</td>
#       <td id="T_581fd_row8_col4" class="data row8 col4" >0.6744</td>
#       <td id="T_581fd_row8_col5" class="data row8 col5" >0.0944</td>
#       <td id="T_581fd_row8_col6" class="data row8 col6" >0.1744</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_581fd_row9_col0" class="data row9 col0" >0.5246</td>
#       <td id="T_581fd_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_581fd_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_581fd_row9_col3" class="data row9 col3" >0.5167</td>
#       <td id="T_581fd_row9_col4" class="data row9 col4" >0.6813</td>
#       <td id="T_581fd_row9_col5" class="data row9 col5" >0.0339</td>
#       <td id="T_581fd_row9_col6" class="data row9 col6" >0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_581fd_row10_col0" class="data row10 col0" >0.5243</td>
#       <td id="T_581fd_row10_col1" class="data row10 col1" >0.5258</td>
#       <td id="T_581fd_row10_col2" class="data row10 col2" >0.9833</td>
#       <td id="T_581fd_row10_col3" class="data row10 col3" >0.5110</td>
#       <td id="T_581fd_row10_col4" class="data row10 col4" >0.6724</td>
#       <td id="T_581fd_row10_col5" class="data row10 col5" >0.0542</td>
#       <td id="T_581fd_row10_col6" class="data row10 col6" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_581fd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_581fd_row11_col0" class="data row11 col0" >0.0251</td>
#       <td id="T_581fd_row11_col1" class="data row11 col1" >0.0240</td>
#       <td id="T_581fd_row11_col2" class="data row11 col2" >0.0307</td>
#       <td id="T_581fd_row11_col3" class="data row11 col3" >0.0148</td>
#       <td
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_8628d_row10_col0, #T_8628d_row10_col1, #T_8628d_row10_col2, #T_8628d_row10_col3, #T_8628d_row10_col4, #T_8628d_row10_col5, #T_8628d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8628d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8628d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8628d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8628d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8628d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8628d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8628d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8628d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8628d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8628d_row0_col0" class="data row0 col0" >0.5323</td>
#       <td id="T_8628d_row0_col1" class="data row0 col1" >0.5323</td>
#       <td id="T_8628d_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_8628d_row0_col3" class="data row0 col3" >0.5167</td>
#       <td id="T_8628d_row0_col4" class="data row0 col4" >0.6813</td>
#       <td id="T_8628d_row0_col5" class="data row0 col5" >0.0645</td>
#       <td id="T_8628d_row0_col6" class="data row0 col6" >0.1826</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8628d_row1_col0" class="data row1 col0" >0.5323</td>
#       <td id="T_8628d_row1_col1" class="data row1 col1" >0.5323</td>
#       <td id="T_8628d_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_8628d_row1_col3" class="data row1 col3" >0.5167</td>
#       <td id="T_8628d_row1_col4" class="data row1 col4" >0.6813</td>
#       <td id="T_8628d_row1_col5" class="data row1 col5" >0.0645</td>
#       <td id="T_8628d_row1_col6" class="data row1 col6" >0.1826</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8628d_row2_col0" class="data row2 col0" >0.5484</td>
#       <td id="T_8628d_row2_col1" class="data row2 col1" >0.5484</td>
#       <td id="T_8628d_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_8628d_row2_col3" class="data row2 col3" >0.5254</td>
#       <td id="T_8628d_row2_col4" class="data row2 col4" >0.6889</td>
#       <td id="T_8628d_row2_col5" class="data row2 col5" >0.0968</td>
#       <td id="T_8628d_row2_col6" class="data row2 col6" >0.2255</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8628d_row3_col0" class="data row3 col0" >0.5645</td>
#       <td id="T_8628d_row3_col1" class="data row3 col1" >0.5645</td>
#       <td id="T_8628d_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_8628d_row3_col3" class="data row3 col3" >0.5345</td>
#       <td id="T_8628d_row3_col4" class="data row3 col4" >0.6966</td>
#       <td id="T_8628d_row3_col5" class="data row3 col5" >0.1290</td>
#       <td id="T_8628d_row3_col6" class="data row3 col6" >0.2626</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8628d_row4_col0" class="data row4 col0" >0.5082</td>
#       <td id="T_8628d_row4_col1" class="data row4 col1" >0.5161</td>
#       <td id="T_8628d_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_8628d_row4_col3" class="data row4 col3" >0.5000</td>
#       <td id="T_8628d_row4_col4" class="data row4 col4" >0.6667</td>
#       <td id="T_8628d_row4_col5" class="data row4 col5" >0.0317</td>
#       <td id="T_8628d_row4_col6" class="data row4 col6" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8628d_row5_col0" class="data row5 col0" >0.5246</td>
#       <td id="T_8628d_row5_col1" class="data row5 col1" >0.5323</td>
#       <td id="T_8628d_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_8628d_row5_col3" class="data row5 col3" >0.5085</td>
#       <td id="T_8628d_row5_col4" class="data row5 col4" >0.6742</td>
#       <td id="T_8628d_row5_col5" class="data row5 col5" >0.0635</td>
#       <td id="T_8628d_row5_col6" class="data row5 col6" >0.1811</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8628d_row6_col0" class="data row6 col0" >0.4754</td>
#       <td id="T_8628d_row6_col1" class="data row6 col1" >0.4833</td>
#       <td id="T_8628d_row6_col2" class="data row6 col2" >0.9667</td>
#       <td id="T_8628d_row6_col3" class="data row6 col3" >0.4833</td>
#       <td id="T_8628d_row6_col4" class="data row6 col4" >0.6444</td>
#       <td id="T_8628d_row6_col5" class="data row6 col5" >-0.0328</td>
#       <td id="T_8628d_row6_col6" class="data row6 col6" >-0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8628d_row7_col0" class="data row7 col0" >0.4918</td>
#       <td id="T_8628d_row7_col1" class="data row7 col1" >0.5016</td>
#       <td id="T_8628d_row7_col2" class="data row7 col2" >0.9000</td>
#       <td id="T_8628d_row7_col3" class="data row7 col3" >0.4909</td>
#       <td id="T_8628d_row7_col4" class="data row7 col4" >0.6353</td>
#       <td id="T_8628d_row7_col5" class="data row7 col5" >-0.0032</td>
#       <td id="T_8628d_row7_col6" class="data row7 col6" >-0.0054</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8628d_row8_col0" class="data row8 col0" >0.5410</td>
#       <td id="T_8628d_row8_col1" class="data row8 col1" >0.5473</td>
#       <td id="T_8628d_row8_col2" class="data row8 col2" >0.9667</td>
#       <td id="T_8628d_row8_col3" class="data row8 col3" >0.5179</td>
#       <td id="T_8628d_row8_col4" class="data row8 col4" >0.6744</td>
#       <td id="T_8628d_row8_col5" class="data row8 col5" >0.0944</td>
#       <td id="T_8628d_row8_col6" class="data row8 col6" >0.1744</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8628d_row9_col0" class="data row9 col0" >0.5246</td>
#       <td id="T_8628d_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_8628d_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_8628d_row9_col3" class="data row9 col3" >0.5167</td>
#       <td id="T_8628d_row9_col4" class="data row9 col4" >0.6813</td>
#       <td id="T_8628d_row9_col5" class="data row9 col5" >0.0339</td>
#       <td id="T_8628d_row9_col6" class="data row9 col6" >0.1312</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8628d_row10_col0" class="data row10 col0" >0.5243</td>
#       <td id="T_8628d_row10_col1" class="data row10 col1" >0.5258</td>
#       <td id="T_8628d_row10_col2" class="data row10 col2" >0.9833</td>
#       <td id="T_8628d_row10_col3" class="data row10 col3" >0.5110</td>
#       <td id="T_8628d_row10_col4" class="data row10 col4" >0.6724</td>
#       <td id="T_8628d_row10_col5" class="data row10 col5" >0.0542</td>
#       <td id="T_8628d_row10_col6" class="data row10 col6" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_8628d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8628d_row11_col0" class="data row11 col0" >0.0251</td>
#       <td id="T_8628d_row11_col1" class="data row11 col1" >0.0240</td>
#       <td id="T_8628d_row11_col2" class="data row11 col2" >0.0307</td>
#       <td id="T_8628d_row11_col3" class="data row11 col3" >0.0148</td>
#       <td
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#%run -t Step5-Measures_PF.ipynb
# Out:
# num samples data: 1536, num_klusters:15
# (1536, 9)
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# __init__.pxd in numpy.import_array()
#
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf . Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem .
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      19         try:
# ---> 20             from pomegranate import BayesianNetwork
#      21         except ImportError:
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/__init__.py in <module>
#      10
# ---> 11 from .base import *
#      12 from .parallel import *
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/base.pyx in init pomegranate.base()
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/distributions/__init__.py in <module>
#       8
# ----> 9 from .distributions import *
#      10
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/distributions/distributions.pyx in init pomegranate.distributions.distributions()
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/utils.pyx in init pomegranate.utils()
#
# __init__.pxd in numpy.import_array()
#
# ImportError: numpy.core.multiarray failed to import
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step5-Measures_PF.ipynb in <cell line: 32>()
#      52         synthetic_data = pd.read_csv(sd_path)
#      53
# ---> 54         pf_measures = compute_all_pf_measures(original_data=original_data,
#      55                                               synthetic_data=synthetic_data,
#      56                                               metadata=metadata,
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/PF_metrics.py in compute_all_pf_measures(original_data, synthetic_data, metadata, SD_id)
#     556     measures["Cluster_1_time"] = result["time"]
#     557
# --> 558     result = BNLogLikelihood_metric(
#     559         original_data=original_data, synthetic_data=synthetic_data, metadata=metadata
#     560     )
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/utils.py in timefunction_wrapper(*args, **kwargs)
#      81     def timefunction_wrapper(*args, **kwargs):
#      82         start_time = time.perf_counter()
# ---> 83         score = func(*args, **kwargs)
#      84         end_time = time.perf_counter()
#      85
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/PF_metrics.py in BNLogLikelihood_metric(original_data, synthetic_data, metadata)
#     400         https://docs.sdv.dev/sdmetrics/metrics/metrics-in-beta/data-likelihood/bnloglikelihood
#     401     """
# --> 402     return BNLogLikelihood.compute(
#     403         real_data=original_data, synthetic_data=synthetic_data, metadata=metadata
#     404     )
#
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in compute(cls, real_data, synthetic_data, metadata, structure)
#     191                 Mean of the log probabilities returned by the Bayesian Network.
#     192         """
# --> 193         likelihoods = cls._likelihoods(real_data, synthetic_data, metadata, structure)
#     194         likelihoods[np.where(likelihoods == 0)] = 1e-8
#     195         return np.mean(np.log(likelihoods))
#
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      20             from pomegranate import BayesianNetwork
#      21         except ImportError:
# ---> 22             raise ImportError('Please install pomegranate with `pip install pomegranate`')
#      23
#      24         real_data, synthetic_data, metadata = cls._validate_inputs(
#
# ImportError: Please install pomegranate with `pip install pomegranate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# __init__.pxd in numpy.import_array()
#
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf . Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem .
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      19         try:
# ---> 20             from pomegranate import BayesianNetwork
#      21         except ImportError:
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/__init__.py in <module>
#      10
# ---> 11 from .base import *
#      12 from .parallel import *
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/base.pyx in init pomegranate.base()
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/distributions/__init__.py in <module>
#       8
# ----> 9 from .distributions import *
#      10
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/distributions/distributions.pyx in init pomegranate.distributions.distributions()
#
# /usr/local/lib/python3.9/dist-packages/pomegranate/utils.pyx in init pomegranate.utils()
#
# __init__.pxd in numpy.import_array()
#
# ImportError: numpy.core.multiarray failed to import
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-7c92a42bda24> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '-t Step5-Measures_PF.ipynb')
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2903                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2904                     if raise_exceptions:
# -> 2905                         result.raise_error()
#    2906                     elif not result.success:
#    2907                         break
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in raise_error(self)
#     347             raise self.error_before_exec
#     348         if self.error_in_exec is not None:
# --> 349             raise self.error_in_exec
#     350
#     351     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-10-10236dd6a09c> in <cell line: 32>()
#      52         synthetic_data = pd.read_csv(sd_path)
#      53
# ---> 54         pf_measures = compute_all_pf_measures(original_data=original_data,
#      55                                               synthetic_data=synthetic_data,
#      56                                               metadata=metadata,
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/PF_metrics.py in compute_all_pf_measures(original_data, synthetic_data, metadata, SD_id)
#     556     measures["Cluster_1_time"] = result["time"]
#     557
# --> 558     result = BNLogLikelihood_metric(
#     559         original_data=original_data, synthetic_data=synthetic_data, metadata=metadata
#     560     )
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/utils.py in timefunction_wrapper(*args, **kwargs)
#      81     def timefunction_wrapper(*args, **kwargs):
#      82         start_time = time.perf_counter()
# ---> 83         score = func(*args, **kwargs)
#      84         end_time = time.perf_counter()
#      85
#
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/../src/PF_metrics.py in BNLogLikelihood_metric(original_data, synthetic_data, metadata)
#     400         https://docs.sdv.dev/sdmetrics/metrics/metrics-in-beta/data-likelihood/bnloglikelihood
#     401     """
# --> 402     return BNLogLikelihood.compute(
#     403         real_data=original_data, synthetic_data=synthetic_data, metadata=metadata
#     404     )
#
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in compute(cls, real_data, synthetic_data, metadata, structure)
#     191                 Mean of the log probabilities returned by the Bayesian Network.
#     192         """
# --> 193         likelihoods = cls._likelihoods(real_data, synthetic_data, metadata, structure)
#     194         likelihoods[np.where(likelihoods == 0)] = 1e-8
#     195         return np.mean(np.log(likelihoods))
#
# /usr/local/lib/python3.9/dist-packages/sdmetrics/single_table/bayesian_network.py in _likelihoods(cls, real_data, synthetic_data, metadata, structure)
#      20             from pomegranate import BayesianNetwork
#      21         except ImportError:
# ---> 22             raise ImportError('Please install pomegranate with `pip install pomegranate`')
#      23
#      24         real_data, synthetic_data, metadata = cls._validate_inputs(
#
# ImportError: Please install pomegranate with `pip install pomegranate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Below are cells tested for making the colab notebook work. They are not needed, but saved here incase.

# %%
"""
# !pip install pycaret
# !pip install pandas-profiling
# !pip install sdv
# !pip install sdmetrics
# !pip install seaborn
# !pip install mlflow
# !pip install scikit-optimize
# !pip install autopep8
# !pip install autoviz
# !pip install kmodes
# !pip install pomegranate==0.14.8
# %cd notebooks
"""

# %%
"""
#Deprecated
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
###Downloads conda installer and makes it runnable
#! wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.1.0-1-Linux-x86_64.sh
#! chmod +x Miniconda3-py39_23.1.0-1-Linux-x86_64.sh

! bash ./Miniconda3-py39_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local
# !conda init
"""

# %%
#Deprecated
#%cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
#!conda update -y conda -n base
#!conda create -y -n master python=3.9.16
#!conda activate master
#!conda env update -f requirements.yaml -n master
#!conda run -n master python -m ipykernel install --user --name master

# %%
#!pip freeze > ../colab_requirements.txt
