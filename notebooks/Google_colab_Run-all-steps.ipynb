# %%
# Mount google drive to colab and change to correct directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# !cat /etc/lsb-release
# !pwd
# !which python
# !python --version
# !conda --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=20.04
# DISTRIB_CODENAME=focal
# DISTRIB_DESCRIPTION="Ubuntu 20.04.5 LTS"
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
# /usr/local/bin/python
# Python 3.9.16
# /bin/bash: conda: command not found
# /env/python
# env: PYTHONPATH=

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2066188157491145349
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14343274496
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3307135126136261285
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# Quickfix for dependencies in colab
# Try to import packages, if exception is thrown install dependencies and kill runtime
try:
  from pycaret.classification import *
except (ImportError, KeyError, ModuleNotFoundError):
  ## code to install dependencies
  # !pip install -r minimal_requirements.txt
  #!pip install pomegranate==0.14.8
  print('Stopping RUNTIME! Colaboratory will restart automatically. Please run again.')
  import os
  os.kill(os.getpid(), 9)

# %%
# %cd notebooks
# Out:
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks

# %%
import sys
import os 
abs_path = os.path.abspath('../src')
sys.path.append('../src')

# %%
# %run -t Step2-Model.ipynb
# Out:
# <style type="text/css">
# #T_5cbe1_row8_col1, #T_5cbe1_row10_col1, #T_5cbe1_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5cbe1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cbe1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5cbe1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cbe1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cbe1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5cbe1_row0_col1" class="data row0 col1" >2835</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5cbe1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5cbe1_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5cbe1_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5cbe1_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5cbe1_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5cbe1_row3_col1" class="data row3 col1" >(70000, 785)</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5cbe1_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5cbe1_row4_col1" class="data row4 col1" >(70000, 785)</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5cbe1_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5cbe1_row5_col1" class="data row5 col1" >(56000, 785)</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5cbe1_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5cbe1_row6_col1" class="data row6 col1" >(14000, 785)</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5cbe1_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5cbe1_row7_col1" class="data row7 col1" >784</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5cbe1_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5cbe1_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5cbe1_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5cbe1_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5cbe1_row10_col0" class="data row10 col0" >Normalize</td>
#       <td id="T_5cbe1_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5cbe1_row11_col0" class="data row11 col0" >Normalize method</td>
#       <td id="T_5cbe1_row11_col1" class="data row11 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5cbe1_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5cbe1_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5cbe1_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5cbe1_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5cbe1_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5cbe1_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5cbe1_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5cbe1_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5cbe1_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5cbe1_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5cbe1_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5cbe1_row17_col1" class="data row17 col1" >D3-mnist</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5cbe1_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5cbe1_row18_col1" class="data row18 col1" >70c1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8f2ae_row10_col0, #T_8f2ae_row10_col1, #T_8f2ae_row10_col2, #T_8f2ae_row10_col3, #T_8f2ae_row10_col4, #T_8f2ae_row10_col5, #T_8f2ae_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8f2ae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f2ae_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8f2ae_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8f2ae_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8f2ae_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8f2ae_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8f2ae_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8f2ae_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f2ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f2ae_row0_col0" class="data row0 col0" >0.9132</td>
#       <td id="T_8f2ae_row0_col1" class="data row0 col1" >0.9928</td>
#       <td id="T_8f2ae_row0_col2" class="data row0 col2" >0.9132</td>
#       <td id="T_8f2ae_row0_col3" class="data row0 col3" >0.9129</td>
#       <td id="T_8f2ae_row0_col4" class="data row0 col4" >0.9128</td>
#       <td id="T_8f2ae_row0_col5" class="data row0 col5" >0.9035</td>
#       <td id="T_8f2ae_row0_col6" class="data row0 col6" >0.9036</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f2ae_row1_col0" class="data row1 col0" >0.9212</td>
#       <td id="T_8f2ae_row1_col1" class="data row1 col1" >0.9928</td>
#       <td id="T_8f2ae_row1_col2" class="data row1 col2" >0.9212</td>
#       <td id="T_8f2ae_row1_col3" class="data row1 col3" >0.9210</td>
#       <td id="T_8f2ae_row1_col4" class="data row1 col4" >0.9209</td>
#       <td id="T_8f2ae_row1_col5" class="data row1 col5" >0.9125</td>
#       <td id="T_8f2ae_row1_col6" class="data row1 col6" >0.9125</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f2ae_row2_col0" class="data row2 col0" >0.9157</td>
#       <td id="T_8f2ae_row2_col1" class="data row2 col1" >0.9932</td>
#       <td id="T_8f2ae_row2_col2" class="data row2 col2" >0.9157</td>
#       <td id="T_8f2ae_row2_col3" class="data row2 col3" >0.9155</td>
#       <td id="T_8f2ae_row2_col4" class="data row2 col4" >0.9153</td>
#       <td id="T_8f2ae_row2_col5" class="data row2 col5" >0.9063</td>
#       <td id="T_8f2ae_row2_col6" class="data row2 col6" >0.9064</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f2ae_row3_col0" class="data row3 col0" >0.9143</td>
#       <td id="T_8f2ae_row3_col1" class="data row3 col1" >0.9928</td>
#       <td id="T_8f2ae_row3_col2" class="data row3 col2" >0.9143</td>
#       <td id="T_8f2ae_row3_col3" class="data row3 col3" >0.9142</td>
#       <td id="T_8f2ae_row3_col4" class="data row3 col4" >0.9140</td>
#       <td id="T_8f2ae_row3_col5" class="data row3 col5" >0.9047</td>
#       <td id="T_8f2ae_row3_col6" class="data row3 col6" >0.9048</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f2ae_row4_col0" class="data row4 col0" >0.9159</td>
#       <td id="T_8f2ae_row4_col1" class="data row4 col1" >0.9926</td>
#       <td id="T_8f2ae_row4_col2" class="data row4 col2" >0.9159</td>
#       <td id="T_8f2ae_row4_col3" class="data row4 col3" >0.9159</td>
#       <td id="T_8f2ae_row4_col4" class="data row4 col4" >0.9157</td>
#       <td id="T_8f2ae_row4_col5" class="data row4 col5" >0.9065</td>
#       <td id="T_8f2ae_row4_col6" class="data row4 col6" >0.9066</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f2ae_row5_col0" class="data row5 col0" >0.9234</td>
#       <td id="T_8f2ae_row5_col1" class="data row5 col1" >0.9930</td>
#       <td id="T_8f2ae_row5_col2" class="data row5 col2" >0.9234</td>
#       <td id="T_8f2ae_row5_col3" class="data row5 col3" >0.9233</td>
#       <td id="T_8f2ae_row5_col4" class="data row5 col4" >0.9232</td>
#       <td id="T_8f2ae_row5_col5" class="data row5 col5" >0.9148</td>
#       <td id="T_8f2ae_row5_col6" class="data row5 col6" >0.9149</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f2ae_row6_col0" class="data row6 col0" >0.9191</td>
#       <td id="T_8f2ae_row6_col1" class="data row6 col1" >0.9926</td>
#       <td id="T_8f2ae_row6_col2" class="data row6 col2" >0.9191</td>
#       <td id="T_8f2ae_row6_col3" class="data row6 col3" >0.9189</td>
#       <td id="T_8f2ae_row6_col4" class="data row6 col4" >0.9189</td>
#       <td id="T_8f2ae_row6_col5" class="data row6 col5" >0.9101</td>
#       <td id="T_8f2ae_row6_col6" class="data row6 col6" >0.9101</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f2ae_row7_col0" class="data row7 col0" >0.9188</td>
#       <td id="T_8f2ae_row7_col1" class="data row7 col1" >0.9937</td>
#       <td id="T_8f2ae_row7_col2" class="data row7 col2" >0.9188</td>
#       <td id="T_8f2ae_row7_col3" class="data row7 col3" >0.9188</td>
#       <td id="T_8f2ae_row7_col4" class="data row7 col4" >0.9183</td>
#       <td id="T_8f2ae_row7_col5" class="data row7 col5" >0.9097</td>
#       <td id="T_8f2ae_row7_col6" class="data row7 col6" >0.9098</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8f2ae_row8_col0" class="data row8 col0" >0.9143</td>
#       <td id="T_8f2ae_row8_col1" class="data row8 col1" >0.9931</td>
#       <td id="T_8f2ae_row8_col2" class="data row8 col2" >0.9143</td>
#       <td id="T_8f2ae_row8_col3" class="data row8 col3" >0.9144</td>
#       <td id="T_8f2ae_row8_col4" class="data row8 col4" >0.9141</td>
#       <td id="T_8f2ae_row8_col5" class="data row8 col5" >0.9047</td>
#       <td id="T_8f2ae_row8_col6" class="data row8 col6" >0.9048</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8f2ae_row9_col0" class="data row9 col0" >0.9204</td>
#       <td id="T_8f2ae_row9_col1" class="data row9 col1" >0.9927</td>
#       <td id="T_8f2ae_row9_col2" class="data row9 col2" >0.9204</td>
#       <td id="T_8f2ae_row9_col3" class="data row9 col3" >0.9200</td>
#       <td id="T_8f2ae_row9_col4" class="data row9 col4" >0.9200</td>
#       <td id="T_8f2ae_row9_col5" class="data row9 col5" >0.9115</td>
#       <td id="T_8f2ae_row9_col6" class="data row9 col6" >0.9115</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8f2ae_row10_col0" class="data row10 col0" >0.9176</td>
#       <td id="T_8f2ae_row10_col1" class="data row10 col1" >0.9929</td>
#       <td id="T_8f2ae_row10_col2" class="data row10 col2" >0.9176</td>
#       <td id="T_8f2ae_row10_col3" class="data row10 col3" >0.9175</td>
#       <td id="T_8f2ae_row10_col4" class="data row10 col4" >0.9173</td>
#       <td id="T_8f2ae_row10_col5" class="data row10 col5" >0.9084</td>
#       <td id="T_8f2ae_row10_col6" class="data row10 col6" >0.9085</td>
#     </tr>
#     <tr>
#       <th id="T_8f2ae_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8f2ae_row11_col0" class="data row11 col0" >0.0033</td>
#       <td id="T_8f2ae_row11_col1" class="data row11 col1" >0.0003</td>
#       <td id="T_8f2ae_row11_col2" class="data row11 col2" >0.0033</td>
#       <td id="T_8f2ae_row11_col3" class="data row11 col3" >0.0032</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# <style type="text/css">
# </style>
# <table id="T_25b7e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25b7e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_25b7e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_25b7e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_25b7e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_25b7e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_25b7e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_25b7e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_25b7e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25b7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25b7e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_25b7e_row0_col1" class="data row0 col1" >0.9196</td>
#       <td id="T_25b7e_row0_col2" class="data row0 col2" >0.9930</td>
#       <td id="T_25b7e_row0_col3" class="data row0 col3" >0.9196</td>
#       <td id="T_25b7e_row0_col4" class="data row0 col4" >0.9194</td>
#       <td id="T_25b7e_row0_col5" class="data row0 col5" >0.9193</td>
#       <td id="T_25b7e_row0_col6" class="data row0 col6" >0.9106</td>
#       <td id="T_25b7e_row0_col7" class="data row0 col7" >0.9106</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /content/drive/Othercomputers/ThinkPad/master-thesis-vt23/notebooks/Step2-Model.ipynb in <cell line: 3>()
#      82             else:
#      83                 m_class = 'raise'
# ---> 84             test_metrics['AUC'] = roc_auc_score(y_true=y_test, y_score=y_pred_score, multi_class=m_class)
#      85
#      86
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     564         if multi_class == "raise":
#     565             raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 566         return _multiclass_roc_auc_score(
#     567             y_true, y_score, labels, multi_class, average, sample_weight
#     568         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     636     """
#     637     # validation of the input y_score
# --> 638     if not np.allclose(1, y_score.sum(axis=1)):
#     639         raise ValueError(
#     640             "Target scores need to be probabilities for multiclass "
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# AxisError: axis 1 is out of bounds for array of dimension 1
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-7-8b569b839698> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '-t Step2-Model.ipynb')
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2903                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2904                     if raise_exceptions:
# -> 2905                         result.raise_error()
#    2906                     elif not result.success:
#    2907                         break
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py in raise_error(self)
#     347             raise self.error_before_exec
#     348         if self.error_in_exec is not None:
# --> 349             raise self.error_in_exec
#     350
#     351     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-7-ea74f800d721> in <cell line: 3>()
#      82             else:
#      83                 m_class = 'raise'
# ---> 84             test_metrics['AUC'] = roc_auc_score(y_true=y_test, y_score=y_pred_score, multi_class=m_class)
#      85
#      86
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     564         if multi_class == "raise":
#     565             raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 566         return _multiclass_roc_auc_score(
#     567             y_true, y_score, labels, multi_class, average, sample_weight
#     568         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     636     """
#     637     # validation of the input y_score
# --> 638     if not np.allclose(1, y_score.sum(axis=1)):
#     639         raise ValueError(
#     640             "Target scores need to be probabilities for multiclass "
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
# %run -t Step3-SDG.ipynb

# %%
# %run -t Step4-SD_models.ipynb

# %%
#%run -t Step5-Measures_PF.ipynb

# %% [markdown]
# Below are cells tested for making the colab notebook work. They are not needed, but saved here incase.

# %%
"""
# !pip install pycaret
# !pip install pandas-profiling
# !pip install sdv
# !pip install sdmetrics
# !pip install seaborn
# !pip install mlflow
# !pip install scikit-optimize
# !pip install autopep8
# !pip install autoviz
# !pip install kmodes
# !pip install pomegranate==0.14.8
# %cd notebooks
"""

# %%
"""
#Deprecated
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
###Downloads conda installer and makes it runnable
#! wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.1.0-1-Linux-x86_64.sh
#! chmod +x Miniconda3-py39_23.1.0-1-Linux-x86_64.sh

! bash ./Miniconda3-py39_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local
# !conda init
"""

# %%
#Deprecated
#%cd /content/drive/Othercomputers/ThinkPad/master-thesis-vt23
#!conda update -y conda -n base
#!conda create -y -n master python=3.9.16
#!conda activate master
#!conda env update -f requirements.yaml -n master
#!conda run -n master python -m ipykernel install --user --name master

# %%
#!pip freeze > ../colab_requirements.txt
